# %%
from datetime import date, datetime, timedelta
from itertools import cycle
import re
import time
import urllib

from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests
from titlecase import titlecase

# to render HTML in Pandas DataFrame output
from IPython.display import display, HTML

# %% [markdown]
# ## Brattle

# %%
url = 'https://brattlefilm.org/coming-soon/'
response = requests.get(url)
text = response.text

soup = BeautifulSoup(text, 'html.parser')

show_details = soup.find_all('div', 'show-details')

# %%
get_dates_raw = lambda x: [' '.join(d.text.split()[1:]) for d in x.find_all('li', 'show-date')]
get_dates = lambda x: [datetime.strptime(d, "%b %d").strftime('%m-%d') for d in get_dates_raw(x)]
get_times = lambda x: [t.text.strip().split('\t')[0].upper() for t in x.find_all('a', 'showtime')]
get_title = lambda x: x.find('a', 'title').text
get_link = lambda x: x.find('a', 'title')['href']
get_poster = lambda x: x.find('div', 'show-poster').img['src']

# %%
brattle_df = pd.DataFrame([{'theater': 'Brattle',
                            'title': get_title(x),
                            'date': d,
                            'time': t,
                            'link': get_link(x),
                            'poster': get_poster(x)}
                           for x in show_details for d,t in list(zip(cycle(get_dates(x)), get_times(x)))])

brattle_df.to_csv('data/brattle.csv', index=False)

# %%
brattle_df = pd.read_csv('data/brattle.csv')
brattle_df.head()
# Out:
#    theater                                   title   date     time  \
# 0  Brattle                   Judgment at Nuremberg  08-22  3:00 PM
# 1  Brattle                   Judgment at Nuremberg  08-22  6:30 PM
# 2  Brattle                      A Child Is Waiting  08-23  4:30 PM
# 3  Brattle                      A Child Is Waiting  08-23  6:45 PM
# 4  Brattle  Harvard Book Store presents R.F. Kuang  08-24  6:00 PM
#
#                                                 link  \
# 0  https://brattlefilm.org/movies/judgment-at-nur...
# 1  https://brattlefilm.org/movies/judgment-at-nur...
# 2  https://brattlefilm.org/movies/a-child-is-wait...
# 3  https://brattlefilm.org/movies/a-child-is-wait...
# 4  https://brattlefilm.org/special_events/harvard...
#
#                                               poster
# 0  https://s3.amazonaws.com/nightjarprod/content/...
# 1  https://s3.amazonaws.com/nightjarprod/content/...
# 2  https://s3.amazonaws.com/nightjarprod/content/...
# 3  https://s3.amazonaws.com/nightjarprod/content/...
# 4  https://s3.amazonaws.com/nightjarprod/content/...

# %% [markdown]
# # Coolidge

# %%
N = 60 # Number of days out to scrape
start_date = date.today()
cur_date = start_date
dates = [(start_date + timedelta(days=n)).strftime('%Y-%m-%d') for n in range(N)]
coolidge_url = 'https://coolidge.org/showtimes?date={date}'

# %%
def film_soup(url):
    c_results = requests.get(url)
    c_soup = BeautifulSoup(c_results.text, 'html.parser')
    c_films = (c_soup.find_all('div', 'film-card'))
    # filter out weird 'ResultSet' objects appearing in results
    c_films = [f for f in c_films if (str(type(f)) == "<class 'bs4.element.Tag'>")] 
    return c_films

# %%
get_title_raw = lambda x: x.find('div', 'film-card__title').text.strip()
get_title = lambda x: re.sub(r'Masked Matinees:', '', get_title_raw(x)).strip()
get_times = lambda x: [t.text.strip() for t in x.find_all('span', 'showtime-ticket__time')]
get_links = lambda x: [t['href'] for t in x.find_all('a', 'showtime-ticket__button')]
get_poster = lambda x: f"https://www.coolidge.org{x.picture.find_all('source')[-1]['srcset'].split()[0]}"

def get_director(x):
    info_link = x.a['href']
    # events have a 'wrapper' page around the movie info itself so update the link
    if info_link.startswith('/event'):
        event_page = requests.get('http://coolidge.org' + info_link)
        event_soup = BeautifulSoup(event_page.text, 'html.parser')
        # return empty string if updating link fails
        try:
            info_link = event_soup.find(class_='film-card__link')['href']
            assert info_link != 'view' # this happens when the Coolidge has dead links!
        except:
            print('Director not found:', info_link)
            return ''
    info_page = requests.get('http://coolidge.org' + info_link)
    info_soup = BeautifulSoup(info_page.text, 'html.parser')
    # return director's name or empty string if not found
    try:
        director = info_soup.find(class_='field--name-field-film-director').find_all('div')[-1].text.strip()
    except:
        print('Director not found:', info_link)
        return ''
    return director

# %%
coolidge_shows = []
for d in dates:
    url =  coolidge_url.format(date=d)
    soup = film_soup(url)
    coolidge_shows.extend([{'theater': 'Coolidge',
                            'title': get_title(x),
                            'date': datetime.strptime(d, "%Y-%m-%d").strftime('%m-%d'),
                            'time': re.sub('(am|pm)', ' \g<1>', t).upper(),
                            'link': l,
                            'poster': get_poster(x),
                            'info': get_director(x)} # used to help RT query
                           for x in soup for t, l in zip(get_times(x), get_links(x))])
    time.sleep(0.25)
                           # for t in get_times(x) for x in soup])
# Out:
# Director not found: /node/43661
# Director not found: /node/43661
# Director not found: view

# %%
coolidge_df = pd.DataFrame(coolidge_shows)
coolidge_df.to_csv('data/coolidge.csv', index=False)

# %%
coolidge_df = pd.read_csv('data/coolidge.csv')
coolidge_df.head()
# Out:
#     theater               title   date     time  \
# 0  Coolidge                Nope  08-22  3:30 PM
# 1  Coolidge                Nope  08-22  6:45 PM
# 2  Coolidge                Nope  08-22  9:30 PM
# 3  Coolidge  Emily the Criminal  08-22  4:15 PM
# 4  Coolidge  Emily the Criminal  08-22  6:30 PM
#
#                                                 link  \
# 0  https://store.coolidge.org/websales/pages/tick...
# 1  https://store.coolidge.org/websales/pages/tick...
# 2  https://store.coolidge.org/websales/pages/tick...
# 3  https://store.coolidge.org/websales/pages/tick...
# 4  https://store.coolidge.org/websales/pages/tick...
#
#                                               poster              info
# 0  https://www.coolidge.org/sites/default/files/s...      Jordan Peele
# 1  https://www.coolidge.org/sites/default/files/s...      Jordan Peele
# 2  https://www.coolidge.org/sites/default/files/s...      Jordan Peele
# 3  https://www.coolidge.org/sites/default/files/s...  John Patton Ford
# 4  https://www.coolidge.org/sites/default/files/s...  John Patton Ford

# %% [markdown]
# ## Somerville Theater

# %%
s_url = 'https://www.somervilletheatre.com/wp-content/themes/somerville/showtimes.xml'
s_results = requests.get(s_url)

s_soup = BeautifulSoup(s_results.text, 'xml')
s_soup = s_soup.find_all('filmtitle')

# %%
get_title_raw = lambda x: titlecase(x.find('name').text)
get_title = lambda x: re.sub(r'(\d\dm{1,2})|(4k)|(Masked Matinees:)', '', get_title_raw(x)).strip()
get_time_raw = lambda x: x.find('show').find('time').text 
get_time = lambda x: datetime.strptime(str(int(get_time_raw(x))//100), '%H').strftime('%l:%M %p').strip()
get_date_raw = lambda x: x.find('show').find('date').text 
get_date = lambda x: datetime.strptime(get_date_raw(x), '%m%d%Y').strftime('%m-%d')
get_link = lambda x: x.show.salelink.text

# %%
somerville_df = pd.DataFrame([{'theater': 'Somerville',
                                 'title': get_title(x), 
                                 'date': get_date(x),
                                 'time': get_time(x),
                                 'link': get_link(x),
                                } for x in s_soup])

somerville_df.to_csv('data/somerville.csv', index=False)

# %%
somerville_df = pd.read_csv('data/somerville.csv')
somerville_df
# Out:
#        theater                    title   date      time  \
# 0   Somerville     Bodies Bodies Bodies  08-22   7:00 PM
# 1   Somerville                 Crooklyn  08-24   9:00 PM
# 2   Somerville            Dirty Dancing  08-22   7:00 PM
# 3   Somerville       Do the Right Thing  08-24   7:00 PM
# 4   Somerville          Friday the 13th  08-27  11:00 PM
# 5   Somerville                Midsommar  08-28   1:00 PM
# 6   Somerville                Nashville  08-30   7:00 PM
# 7   Somerville                     Nope  08-22   7:00 PM
# 8   Somerville             Now and Then  08-22   9:00 PM
# 9   Somerville           On Golden Pond  08-26   7:00 PM
# 10  Somerville  Season of the Witch '72  08-28   4:00 PM
# 11  Somerville              Stand by Me  08-26   5:00 PM
#
#                                                  link
# 0   https://20163.formovietickets.com:2235/T.ASP?W...
# 1   https://20163.formovietickets.com:2235/T.ASP?W...
# 2   https://20163.formovietickets.com:2235/T.ASP?W...
# 3   https://20163.formovietickets.com:2235/T.ASP?W...
# 4   https://20163.formovietickets.com:2235/T.ASP?W...
# 5   https://20163.formovietickets.com:2235/T.ASP?W...
# 6   https://20163.formovietickets.com:2235/T.ASP?W...
# 7   https://20163.formovietickets.com:2235/T.ASP?W...
# 8   https://20163.formovietickets.com:2235/T.ASP?W...
# 9   https://20163.formovietickets.com:2235/T.ASP?W...
# 10  https://20163.formovietickets.com:2235/T.ASP?W...
# 11  https://20163.formovietickets.com:2235/T.ASP?W...

# %% [markdown]
# # Merging

# %%
df = pd.concat([brattle_df, coolidge_df, somerville_df]).sort_values(['date', 'time'])
df['info'] = df['info'].fillna('')
df[:25]
# Out:
#        theater                  title   date     time  \
# 0      Brattle  Judgment at Nuremberg  08-22  3:00 PM
# 0     Coolidge                   Nope  08-22  3:30 PM
# 3     Coolidge     Emily the Criminal  08-22  4:15 PM
# 6     Coolidge   Bodies Bodies Bodies  08-22  4:45 PM
# 1      Brattle  Judgment at Nuremberg  08-22  6:30 PM
# 4     Coolidge     Emily the Criminal  08-22  6:30 PM
# 1     Coolidge                   Nope  08-22  6:45 PM
# 9     Coolidge              Labyrinth  08-22  7:00 PM
# 0   Somerville   Bodies Bodies Bodies  08-22  7:00 PM
# 2   Somerville          Dirty Dancing  08-22  7:00 PM
# 7   Somerville                   Nope  08-22  7:00 PM
# 7     Coolidge   Bodies Bodies Bodies  08-22  7:15 PM
# 10    Coolidge              Vengeance  08-22  9:00 PM
# 8   Somerville           Now and Then  08-22  9:00 PM
# 5     Coolidge     Emily the Criminal  08-22  9:15 PM
# 2     Coolidge                   Nope  08-22  9:30 PM
# 8     Coolidge   Bodies Bodies Bodies  08-22  9:45 PM
# 11    Coolidge                   Nope  08-23  3:30 PM
# 14    Coolidge     Emily the Criminal  08-23  4:15 PM
# 2      Brattle     A Child Is Waiting  08-23  4:30 PM
# 17    Coolidge   Bodies Bodies Bodies  08-23  4:45 PM
# 15    Coolidge     Emily the Criminal  08-23  6:30 PM
# 3      Brattle     A Child Is Waiting  08-23  6:45 PM
# 12    Coolidge                   Nope  08-23  6:45 PM
# 20    Coolidge                Onibaba  08-23  7:00 PM
#
#                                                  link  \
# 0   https://brattlefilm.org/movies/judgment-at-nur...
# 0   https://store.coolidge.org/websales/pages/tick...
# 3   https://store.coolidge.org/websales/pages/tick...
# 6   https://store.coolidge.org/websales/pages/tick...
# 1   https://brattlefilm.org/movies/judgment-at-nur...
# 4   https://store.coolidge.org/websales/pages/tick...
# 1   https://store.coolidge.org/websales/pages/tick...
# 9   https://store.coolidge.org/websales/pages/tick...
# 0   https://20163.formovietickets.com:2235/T.ASP?W...
# 2   https://20163.formovietickets.com:2235/T.ASP?W...
# 7   https://20163.formovietickets.com:2235/T.ASP?W...
# 7   https://store.coolidge.org/websales/pages/tick...
# 10  https://store.coolidge.org/websales/pages/tick...
# 8   https://20163.formovietickets.com:2235/T.ASP?W...
# 5   https://store.coolidge.org/websales/pages/tick...
# 2   https://store.coolidge.org/websales/pages/tick...
# 8   https://store.coolidge.org/websales/pages/tick...
# 11  https://store.coolidge.org/websales/pages/tick...
# 14  https://store.coolidge.org/websales/pages/tick...
# 2   https://brattlefilm.org/movies/a-child-is-wait...
# 17  https://store.coolidge.org/websales/pages/tick...
# 15  https://store.coolidge.org/websales/pages/tick...
# 3   https://brattlefilm.org/movies/a-child-is-wait...
# 12  https://store.coolidge.org/websales/pages/tick...
# 20  https://store.coolidge.org/websales/pages/tick...
#
#                                                poster              info
# 0   https://s3.amazonaws.com/nightjarprod/content/...
# 0   https://www.coolidge.org/sites/default/files/s...      Jordan Peele
# 3   https://www.coolidge.org/sites/default/files/s...  John Patton Ford
# 6   https://www.coolidge.org/sites/default/files/s...      Halina Reijn
# 1   https://s3.amazonaws.com/nightjarprod/content/...
# 4   https://www.coolidge.org/sites/default/files/s...  John Patton Ford
# 1   https://www.coolidge.org/sites/default/files/s...      Jordan Peele
# 9   https://www.coolidge.org/sites/default/files/s...        Jim Henson
# 0                                                 NaN
# 2                                                 NaN
# 7                                                 NaN
# 7   https://www.coolidge.org/sites/default/files/s...      Halina Reijn
# 10  https://www.coolidge.org/sites/default/files/s...        B.J. Novak
# 8                                                 NaN
# 5   https://www.coolidge.org/sites/default/files/s...  John Patton Ford
# 2   https://www.coolidge.org/sites/default/files/s...      Jordan Peele
# 8   https://www.coolidge.org/sites/default/files/s...      Halina Reijn
# 11  https://www.coolidge.org/sites/default/files/s...      Jordan Peele
# 14  https://www.coolidge.org/sites/default/files/s...  John Patton Ford
# 2   https://s3.amazonaws.com/nightjarprod/content/...
# 17  https://www.coolidge.org/sites/default/files/s...      Halina Reijn
# 15  https://www.coolidge.org/sites/default/files/s...  John Patton Ford
# 3   https://s3.amazonaws.com/nightjarprod/content/...
# 12  https://www.coolidge.org/sites/default/files/s...      Jordan Peele
# 20  https://www.coolidge.org/sites/default/files/s...     Kaneto Shindô

# %% [markdown]
# ## Rotten Tomates for poster art and rating

# %% [markdown]
# The movie nameentires on the theater sites are sometimes sloppy and the RT search functionality is very limited.
# Output below tries to identify (some) possible false matches.
#
# The is very hacky and still grabs some wrongs posters and ratings, usually when there are multiple (rated) movies with the same title.
#
# RT has their search results sorted by year. This stinks. Querying "The Thing" doesn't even show the cult classic 1986 Carpenter movie until the 2nd page of results!
#
# I'm probably just going to throw in the towel trying to scrape this info in the future and instead try an API or leverarge work other people have already done like this: https://pypi.org/project/rotten_tomatoes_client/

# %%
rt_df = pd.read_csv('data/rt.csv')
# rt_df.head()

# %%
def get_rt_info(query):
    N = 10 # number of entries to consider
    query_parsed = urllib.parse.quote(query)
    url = "https://rottentomatoes.com/search?search='{query_parsed}'"
    url = url.format(query_parsed=query_parsed)
    result = requests.get(url)
    soup = BeautifulSoup(result.content, 'html.parser')
    movie_section = soup.find('h2', attrs={'data-qa': 'search-result-title'}, text='Movies')
    listings = movie_section.find_next_sibling('ul').find_all('search-page-media-row')
    scores = [int(m['tomatometerscore']) if m['tomatometerscore'].isnumeric() else 0 for m in listings]
    # accept first exact title match that has a rating or highest rated listing if no exact match
    try:
        rated_listings = [x[0] for x in sorted(zip(listings[:N], scores), key=lambda x: x[1], reverse=True) if x[1] > 0]
        titles = [x.text.strip().lower() for x in rated_listings]
        entry = rated_listings[titles.index(query.split('|')[0].strip().lower())]
        exact_match = True
    except:
        entry = listings[np.argmax(scores[:N])]
        exact_match = False
        print(f"No exact match for \"{query}\", usings \"{entry.text.strip()}\" instead")
    try:
        rt_info = {
            'title': entry.text.strip(),
            'poster': entry.img['src'],
            'year': entry['releaseyear'],
            'cast': entry['cast'],
            'score': entry['tomatometerscore'], # technically redundant
            'cert': entry['tomatometerstate'],
            'rt_link': entry.a['href'],
            'exact_match': exact_match,
            'query_str': query # the string query that resulted in this info (for caching)
            }
    except:
        return None
    return rt_info

# %%
# %%time
# example
get_rt_info("Vengeance | Novak")
# Out:
# CPU times: user 98.2 ms, sys: 266 µs, total: 98.4 ms
# Wall time: 443 ms
# {'title': 'Vengeance',
#  'poster': 'https://resizing.flixster.com/YQlnTBaOXZazET7DPeIiueFGsDE=/fit-in/80x126/v2/https://resizing.flixster.com/xrx35GfPi6i2xPLrmj30cYIKO4c=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzdiZTdkNDdlLWE5M2EtNDNhNC1hYWE2LTljYzJjYjc3ZDc2OC5qcGc=',
#  'year': '2022',
#  'cast': 'B.J. Novak,Issa Rae,Ashton Kutcher',
#  'score': '79',
#  'cert': 'certified-fresh',
#  'rt_link': 'https://www.rottentomatoes.com/m/vengeance_2022',
#  'exact_match': True,
#  'query_str': 'Vengeance | Novak'}

# %%
# %%time
SLEEP_TIME = 0.1 # let's be nice and not hammer the servers too hard
no_dupes = df.drop_duplicates(['title', 'info'])
rt_data = []
for title, info in zip(no_dupes['title'], no_dupes['info']):
    # title and info delimited by '|' so it can be decomposed later
    query = f'{title} | {info}'.strip()
    try:
        d = get_rt_info(query)
        d.update(listing_title=title)
        rt_data.append(d)
    except:
        print(title, info)
    time.sleep(SLEEP_TIME)
# Out:
# No exact match for "Harvard Book Store presents R.F. Kuang |", usings "Hello, Bookstore" instead
# No exact match for "Kill Bill Vol. 1 and Vol. 2 | Quentin Tarantino", usings "A One and a Two..." instead
# No exact match for "Rock ‘n’ Roll High School |", usings "Rock 'n' Roll High School" instead
# No exact match for "The Origins of American Independent Cinema
#
#
#
# Part of The Origins of American Independent Cinema |", usings "The Decline of Western Civilization Part II: The Metal Years" instead
# No exact match for "X (2022) | Ti West", usings "X" instead
# No exact match for "Road Warrior (aka Mad Max 2) |", usings "Mad Max: Fury Road" instead
# No exact match for "The Texas Chainsaw Massacre 2 | Tobe Hooper", usings "The Texas Chainsaw Massacre Part 2" instead
# No exact match for "Season of the Witch '72 |", usings "Season of the Devil (Ang Panahon ng Halimaw)" instead
# No exact match for "Straight Line Crazy | Nicholas Hytner", usings "The Lady in the Van" instead
# No exact match for "Shaft (1971) | Gordon Parks", usings "A Choice of Weapons: Inspired by Gordon Parks" instead
# No exact match for "Coolidge After Midnite Honors Fabio Frizzi
#
#
#
# Part of Coolidge After Midnite Honors Fabio Frizzi | Lucio Fulci", usings "Fulci for Fake" instead
# No exact match for "Frizzi 2 Fulci
#
#
#
# Part of Coolidge After Midnite Honors Fabio Frizzi |", usings "Fulci for Fake" instead
# No exact match for "Infernal Affairs Trilogy | Andrew Lau, Alan Mak", usings "Infernal Affairs" instead
# No exact match for "Greg Sestero Presents Miracle Valley and The Room | Greg Sestero", usings "Infrared" instead
# No exact match for "Three Colors: Blue | Krzysztof Kieslowski", usings "Blue" instead
# No exact match for "Three Colors: White | Krzysztof Kieslowski", usings "Trois Couleurs: Blanc" instead
# No exact match for "Jack Absolute Flies Again | Emily Burns", usings "Daphne" instead
# No exact match for "The Thing (1982) | John Carpenter", usings "The Thing" instead
# No exact match for "The Greatest Showman Sing-Along | Michael Gracey", usings "Monty Python and the Holy Grail" instead
# CPU times: user 8.65 s, sys: 253 ms, total: 8.9 s
# Wall time: 1min 21s

# %%
rt_df = pd.DataFrame(rt_data)
rt_df.to_csv('data/rt.csv', index=False)

# %%
rt_df = pd.read_csv('data/rt.csv')
rt_df.head()
# Out:
#                    title                                             poster  \
# 0  Judgment at Nuremberg  https://resizing.flixster.com/aOTyYtddK0xgxGIT...
# 1                   Nope  https://resizing.flixster.com/RqUUghr84Wd1Mdr_...
# 2     Emily the Criminal  https://resizing.flixster.com/i7JSTWsBKyKdjQKi...
# 3   Bodies Bodies Bodies  https://resizing.flixster.com/wUsCy5Orzb86Dexq...
# 4              Labyrinth  https://resizing.flixster.com/jNnX_xp8w6xznQPx...
#
#    year                                             cast  score  \
# 0  1961     Spencer Tracy,Burt Lancaster,Richard Widmark     92
# 1  2022           Daniel Kaluuya,Keke Palmer,Steven Yeun     82
# 2  2022        Aubrey Plaza,Theo Rossi,Jonathan Avigdori     93
# 3  2022  Amandla Stenberg,Maria Bakalova,Myha'la Herrold     88
# 4  1986         David Bowie,Jennifer Connelly,Toby Froud     75
#
#               cert                                            rt_link  \
# 0            fresh  https://www.rottentomatoes.com/m/judgment_at_n...
# 1  certified-fresh              https://www.rottentomatoes.com/m/nope
# 2  certified-fresh  https://www.rottentomatoes.com/m/emily_the_cri...
# 3  certified-fresh  https://www.rottentomatoes.com/m/bodies_bodies...
# 4            fresh         https://www.rottentomatoes.com/m/labyrinth
#
#    exact_match                              query_str          listing_title
# 0         True                Judgment at Nuremberg |  Judgment at Nuremberg
# 1         True                    Nope | Jordan Peele                   Nope
# 2         True  Emily the Criminal | John Patton Ford     Emily the Criminal
# 3         True    Bodies Bodies Bodies | Halina Reijn   Bodies Bodies Bodies
# 4         True                 Labyrinth | Jim Henson              Labyrinth

# %%
merged = pd.merge(df, rt_df, left_on='title', right_on='listing_title')

# %%
merged.columns
# Out:
# Index(['theater', 'title_x', 'date', 'time', 'link', 'poster_x', 'info',
#        'title_y', 'poster_y', 'year', 'cast', 'score', 'cert', 'rt_link',
#        'exact_match', 'query_str', 'listing_title'],
#       dtype='object')

# %%
merged = merged.drop(['listing_title', 'poster_x', 'title_y'], axis=1)\
               .rename(columns={'title_x': 'title', 'poster_y': 'poster'})

# %%
output = merged[['theater', 'poster', 'exact_match', 'title', 'year', 'date', 'time', 'link', 'score', 'rt_link']].sort_values(['date','time'])
output= output.drop_duplicates()

# %%
# add HTML to poster and ticket & RT link strings so they 
# work when displayed in the DataFrame
output['exact_match'] = output.exact_match.apply(lambda x: '?' if not x else ' ')
output['poster']=  '''<img src="''' + output['poster'] + '''">''' 
output['link'] = output.link.apply(lambda x: f"<a href={x}>🎟️</a>")
output['rt_link'] = output.rt_link.apply(lambda x: f"<a href={x}>🍅</a>")

# %%
output.to_csv("data/showtimes.csv")

# %% [markdown]
# # Showtimes

# %%
html_output = r'<link rel="stylesheet" type="text/css" media="screen" href="stylesheets/main.css" />' + '\n'

html_output += output.to_html(render_links=True, escape=False, index=False, justify='center')
with open('docs/index.html', 'w') as f:
    f.write(html_output)

# %%
HTML(output.to_html(render_links=True, escape=False, index=False, justify='center'))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th>theater</th>
#       <th>poster</th>
#       <th>exact_match</th>
#       <th>title</th>
#       <th>year</th>
#       <th>date</th>
#       <th>time</th>
#       <th>link</th>
#       <th>score</th>
#       <th>rt_link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Brattle</td>
#       <td><img src="https://resizing.flixster.com/aOTyYtddK0xgxGITaMOzF6Nqxj4=/fit-in/80x126/v2/https://flxt.tmsimg.com/assets/p2664_p_v8_ab.jpg"></td>
#       <td></td>
#       <td>Judgment at Nuremberg</td>
#       <td>1961</td>
#       <td>08-22</td>
#       <td>3:00 PM</td>
#       <td><a href=https://brattlefilm.org/movies/judgment-at-nuremberg/>🎟️</a></td>
#       <td>92</td>
#       <td><a href=https://www.rottentomatoes.com/m/judgment_at_nuremburg>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/RqUUghr84Wd1Mdr_7PStmSQXXhM=/fit-in/80x126/v2/https://resizing.flixster.com/6EeYrywKueOFue9uRSQqLxfGKI0=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzA0NzZhZTk0LTI3NjctNGZiNi04Yjg4LWRiN2RkNTJiYWZlNy5qcGc="></td>
#       <td></td>
#       <td>Nope</td>
#       <td>2022</td>
#       <td>08-22</td>
#       <td>3:30 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/ticketsearchcriteria.aspx?evtinfo=751551~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>82</td>
#       <td><a href=https://www.rottentomatoes.com/m/nope>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/i7JSTWsBKyKdjQKiLGIWLLSKJz8=/fit-in/80x126/v2/https://resizing.flixster.com/qtYisqOwDStnpo2P22PRTHC53Uk=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL2NmMmQ0ZTRiLWVkOGYtNDllNS05ZjRiLWYyY2RhMjk1YzRjYi5qcGc="></td>
#       <td></td>
#       <td>Emily the Criminal</td>
#       <td>2022</td>
#       <td>08-22</td>
#       <td>4:15 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/ticketsearchcriteria.aspx?evtinfo=751604~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>93</td>
#       <td><a href=https://www.rottentomatoes.com/m/emily_the_criminal>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/wUsCy5Orzb86DexqthsfuvpaBbA=/fit-in/80x126/v2/https://resizing.flixster.com/fvOZsuAVLTdhl2l-2GujLRXhcXQ=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL2Y0MmI1ZTBmLThjNjQtNDg0NC04ZDk4LTk3YTE0NjAyZGM3Mi5wbmc="></td>
#       <td></td>
#       <td>Bodies Bodies Bodies</td>
#       <td>2022</td>
#       <td>08-22</td>
#       <td>4:45 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/ticketsearchcriteria.aspx?evtinfo=751562~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>88</td>
#       <td><a href=https://www.rottentomatoes.com/m/bodies_bodies_bodies>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Brattle</td>
#       <td><img src="https://resizing.flixster.com/aOTyYtddK0xgxGITaMOzF6Nqxj4=/fit-in/80x126/v2/https://flxt.tmsimg.com/assets/p2664_p_v8_ab.jpg"></td>
#       <td></td>
#       <td>Judgment at Nuremberg</td>
#       <td>1961</td>
#       <td>08-22</td>
#       <td>6:30 PM</td>
#       <td><a href=https://brattlefilm.org/movies/judgment-at-nuremberg/>🎟️</a></td>
#       <td>92</td>
#       <td><a href=https://www.rottentomatoes.com/m/judgment_at_nuremburg>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/i7JSTWsBKyKdjQKiLGIWLLSKJz8=/fit-in/80x126/v2/https://resizing.flixster.com/qtYisqOwDStnpo2P22PRTHC53Uk=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL2NmMmQ0ZTRiLWVkOGYtNDllNS05ZjRiLWYyY2RhMjk1YzRjYi5qcGc="></td>
#       <td></td>
#       <td>Emily the Criminal</td>
#       <td>2022</td>
#       <td>08-22</td>
#       <td>6:30 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/ticketsearchcriteria.aspx?evtinfo=751583~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>93</td>
#       <td><a href=https://www.rottentomatoes.com/m/emily_the_criminal>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/RqUUghr84Wd1Mdr_7PStmSQXXhM=/fit-in/80x126/v2/https://resizing.flixster.com/6EeYrywKueOFue9uRSQqLxfGKI0=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzA0NzZhZTk0LTI3NjctNGZiNi04Yjg4LWRiN2RkNTJiYWZlNy5qcGc="></td>
#       <td></td>
#       <td>Nope</td>
#       <td>2022</td>
#       <td>08-22</td>
#       <td>6:45 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/ticketsearchcriteria.aspx?evtinfo=751540~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>82</td>
#       <td><a href=https://www.rottentomatoes.com/m/nope>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Somerville</td>
#       <td><img src="https://resizing.flixster.com/RqUUghr84Wd1Mdr_7PStmSQXXhM=/fit-in/80x126/v2/https://resizing.flixster.com/6EeYrywKueOFue9uRSQqLxfGKI0=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzA0NzZhZTk0LTI3NjctNGZiNi04Yjg4LWRiN2RkNTJiYWZlNy5qcGc="></td>
#       <td></td>
#       <td>Nope</td>
#       <td>2022</td>
#       <td>08-22</td>
#       <td>7:00 PM</td>
#       <td><a href=https://20163.formovietickets.com:2235/T.ASP?WCI=BT&Page=PickTickets&SHOWID=42417&PLACEID=3>🎟️</a></td>
#       <td>82</td>
#       <td><a href=https://www.rottentomatoes.com/m/nope>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Somerville</td>
#       <td><img src="https://resizing.flixster.com/wUsCy5Orzb86DexqthsfuvpaBbA=/fit-in/80x126/v2/https://resizing.flixster.com/fvOZsuAVLTdhl2l-2GujLRXhcXQ=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL2Y0MmI1ZTBmLThjNjQtNDg0NC04ZDk4LTk3YTE0NjAyZGM3Mi5wbmc="></td>
#       <td></td>
#       <td>Bodies Bodies Bodies</td>
#       <td>2022</td>
#       <td>08-22</td>
#       <td>7:00 PM</td>
#       <td><a href=https://20163.formovietickets.com:2235/T.ASP?WCI=BT&Page=PickTickets&SHOWID=42418&PLACEID=2>🎟️</a></td>
#       <td>88</td>
#       <td><a href=https://www.rottentomatoes.com/m/bodies_bodies_bodies>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/jNnX_xp8w6xznQPxCH9vpnd3DWs=/fit-in/80x126/v2/https://flxt.tmsimg.com/assets/p9355_p_v7_ak.jpg"></td>
#       <td></td>
#       <td>Labyrinth</td>
#       <td>1986</td>
#       <td>08-22</td>
#       <td>7:00 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/ticketsearchcriteria.aspx?evtinfo=729489~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>75</td>
#       <td><a href=https://www.rottentomatoes.com/m/labyrinth>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Somerville</td>
#       <td><img src="https://resizing.flixster.com/AHDUrGor402_frmoRkntUNg_5RA=/fit-in/80x126/v2/https://flxt.tmsimg.com/NowShowing/2027/2027_aa.jpg"></td>
#       <td></td>
#       <td>Dirty Dancing</td>
#       <td>1987</td>
#       <td>08-22</td>
#       <td>7:00 PM</td>
#       <td><a href=https://20163.formovietickets.com:2235/T.ASP?WCI=BT&Page=PickTickets&SHOWID=42073&PLACEID=1>🎟️</a></td>
#       <td>70</td>
#       <td><a href=https://www.rottentomatoes.com/m/dirty_dancing>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/wUsCy5Orzb86DexqthsfuvpaBbA=/fit-in/80x126/v2/https://resizing.flixster.com/fvOZsuAVLTdhl2l-2GujLRXhcXQ=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL2Y0MmI1ZTBmLThjNjQtNDg0NC04ZDk4LTk3YTE0NjAyZGM3Mi5wbmc="></td>
#       <td></td>
#       <td>Bodies Bodies Bodies</td>
#       <td>2022</td>
#       <td>08-22</td>
#       <td>7:15 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/ticketsearchcriteria.aspx?evtinfo=751570~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>88</td>
#       <td><a href=https://www.rottentomatoes.com/m/bodies_bodies_bodies>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/YQlnTBaOXZazET7DPeIiueFGsDE=/fit-in/80x126/v2/https://resizing.flixster.com/xrx35GfPi6i2xPLrmj30cYIKO4c=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzdiZTdkNDdlLWE5M2EtNDNhNC1hYWE2LTljYzJjYjc3ZDc2OC5qcGc="></td>
#       <td></td>
#       <td>Vengeance</td>
#       <td>2022</td>
#       <td>08-22</td>
#       <td>9:00 PM</td>
#       <td><a href=https://store.coolidge.org/websales

# %% [markdown]
# **Different movies playing today**

# %%
df[df['date'] == date.today().strftime('%m-%d')].title.unique()
# Out:
# array(['Judgment at Nuremberg', 'Nope', 'Emily the Criminal',
#        'Bodies Bodies Bodies', 'Labyrinth', 'Dirty Dancing', 'Vengeance',
#        'Now and Then'], dtype=object)
