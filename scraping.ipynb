# %%
from datetime import date, datetime, timedelta
import time
import re
import urllib
import numpy as np
import requests
import titlecase
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display, HTML

# %% [markdown]
# ## Brattle

# %%
url = 'https://brattlefilm.org/coming-soon/'
response = requests.get(url)
text = response.text

soup = BeautifulSoup(text, 'html.parser')

show_details = soup.find_all('div', 'show-details')

# %%
get_dates_raw = lambda x: [' '.join(d.text.split()[1:]) for d in x.find_all('li', 'show-date')]
get_dates = lambda x: [datetime.strptime(d, "%b %d").strftime('%m-%d') for d in get_dates_raw(x)]
get_times = lambda x: [t.text.strip().split('\t')[0].upper() for t in x.find_all('a', 'showtime')]
get_title = lambda x: x.find('a', 'title').text
get_link = lambda x: x.find('a', 'title')['href']
get_poster = lambda x: x.find('div', 'show-poster').img['src']

# %%
brattle_df = pd.DataFrame([{'theater': 'Brattle',
                            'title': get_title(x),
                            'date': d,
                            'time': t,
                            'link': get_link(x),
                            'poster': get_poster(x)}
                           for x in show_details for d,t in list(zip(get_dates(x), get_times(x)))])

brattle_df.to_csv('data/brattle.csv', index=False)

# %%
brattle_df = pd.read_csv('data/brattle.csv')
brattle_df.head(20)
# Out:
#     theater                                title   date      time  \
# 0   Brattle                              El Topo  08-11   7:00 PM
# 1   Brattle                    The Holy Mountain  08-11   9:45 PM
# 2   Brattle                              Morocco  08-12   5:00 PM
# 3   Brattle                           Dishonored  08-12   7:00 PM
# 4   Brattle                         Blonde Venus  08-13   3:00 PM
# 5   Brattle                     Shanghai Express  08-13   5:00 PM
# 6   Brattle                 The Devil Is a Woman  08-14  12:30 PM
# 7   Brattle                  The Scarlet Empress  08-14   2:30 PM
# 8   Brattle                    For Me and My Gal  08-15   4:15 PM
# 9   Brattle                         Summer Stock  08-15   6:30 PM
# 10  Brattle                           The Pirate  08-16   4:15 PM
# 11  Brattle                           Fish & Men  08-17   6:30 PM
# 12  Brattle                            Identikit  08-17   9:00 PM
# 13  Brattle         The Texas Chain Saw Massacre  08-18   5:00 PM
# 14  Brattle             Night of the Living Dead  08-18   7:00 PM
# 15  Brattle              Blade Runner: Final Cut  08-19   4:30 PM
# 16  Brattle              Blade Runner: Final Cut  08-21   9:30 PM
# 17  Brattle                            The Thing  08-19   7:00 PM
# 18  Brattle                Bonnie ‘Prince’ Billy  08-20   8:00 PM
# 19  Brattle  Brittany Gravely: Vignettes of Time  08-21   2:00 PM
#
#                                                  link  \
# 0             https://brattlefilm.org/movies/el-topo/
# 1   https://brattlefilm.org/movies/the-holy-mountain/
# 2             https://brattlefilm.org/movies/morocco/
# 3          https://brattlefilm.org/movies/dishonored/
# 4        https://brattlefilm.org/movies/blonde-venus/
# 5    https://brattlefilm.org/movies/shanghai-express/
# 6   https://brattlefilm.org/movies/the-devil-is-a-...
# 7   https://brattlefilm.org/movies/the-scarlet-emp...
# 8   https://brattlefilm.org/movies/for-me-and-my-gal/
# 9        https://brattlefilm.org/movies/summer-stock/
# 10         https://brattlefilm.org/movies/the-pirate/
# 11           https://brattlefilm.org/movies/fish-men/
# 12          https://brattlefilm.org/movies/identikit/
# 13  https://brattlefilm.org/movies/the-texas-chain...
# 14  https://brattlefilm.org/movies/night-of-the-li...
# 15       https://brattlefilm.org/movies/blade-runner/
# 16       https://brattlefilm.org/movies/blade-runner/
# 17          https://brattlefilm.org/movies/the-thing/
# 18  https://brattlefilm.org/special_events/bonnie-...
# 19  https://brattlefilm.org/special_events/brittan...
#
#                                                poster
# 0   https://s3.amazonaws.com/nightjarprod/content/...
# 1   https://s3.amazonaws.com/nightjarprod/content/...
# 2   https://s3.amazonaws.com/nightjarprod/content/...
# 3   https://s3.amazonaws.com/nightjarprod/content/...
# 4   https://s3.amazonaws.com/nightjarprod/content/...
# 5   https://s3.amazonaws.com/nightjarprod/content/...
# 6   https://s3.amazonaws.com/nightjarprod/content/...
# 7   https://s3.amazonaws.com/nightjarprod/content/...
# 8   https://s3.amazonaws.com/nightjarprod/content/...
# 9   https://s3.amazonaws.com/nightjarprod/content/...
# 10  https://s3.amazonaws.com/nightjarprod/content/...
# 11  https://s3.amazonaws.com/nightjarprod/content/...
# 12  https://s3.amazonaws.com/nightjarprod/content/...
# 13  https://s3.amazonaws.com/nightjarprod/content/...
# 14  https://s3.amazonaws.com/nightjarprod/content/...
# 15  https://s3.amazonaws.com/nightjarprod/content/...
# 16  https://s3.amazonaws.com/nightjarprod/content/...
# 17  https://s3.amazonaws.com/nightjarprod/content/...
# 18  https://s3.amazonaws.com/nightjarprod/content/...
# 19  https://s3.amazonaws.com/nightjarprod/content/...

# %% [markdown]
# # Coolidge

# %%
N = 60 # Number of days scrape
start_date = date.today()
cur_date = start_date
dates = [(start_date + timedelta(days=n)).strftime('%Y-%m-%d') for n in range(N)]
coolidge_url = 'https://coolidge.org/showtimes?date={date}'

# %%
def film_soup(url):
    c_results = requests.get(url)
    c_soup = BeautifulSoup(c_results.text, 'html.parser')
    c_films = (c_soup.find_all('div', 'film-card'))
    # filter out weird 'ResultSet' objects appearing in results
    c_films = [f for f in c_films if (str(type(f)) == "<class 'bs4.element.Tag'>")] 
    return c_films

# %%
get_title_raw = lambda x: x.find('div', 'film-card__title').text.strip()
get_title = lambda x: re.sub(r'Masked Matinees:', '', get_title_raw(x)).strip()
get_times = lambda x: [t.text.strip() for t in x.find_all('span', 'showtime-ticket__time')]
get_links = lambda x: [t['href'] for t in x.find_all('a', 'showtime-ticket__button')]
get_poster = lambda x: f"https://www.coolidge.org{x.picture.find_all('source')[-1]['srcset'].split()[0]}"

# %%
coolidge_shows = []
for d in dates:
    url =  coolidge_url.format(date=d)
    soup = film_soup(url)
    coolidge_shows.extend([{'theater': 'Coolidge',
                            'title': get_title(x),
                            'date': datetime.strptime(d, "%Y-%m-%d").strftime('%m-%d'),
                            'time': re.sub('(am|pm)', ' \g<1>', t).upper(),
                            'link': l,
                            'poster': get_poster(x)}
                           for x in soup for t, l in zip(get_times(x), get_links(x))])
                           # for t in get_times(x) for x in soup])

# %%
coolidge_df = pd.DataFrame(coolidge_shows)
coolidge_df.to_csv('data/coolidge.csv', index=False)

# %%
coolidge_df = pd.read_csv('data/coolidge.csv')
coolidge_df.head(20)
# Out:
#      theater                                              title   date  \
# 0   Coolidge                                               Nope  08-11
# 1   Coolidge                                               Nope  08-11
# 2   Coolidge                                               Nope  08-11
# 3   Coolidge                                       Bullet Train  08-11
# 4   Coolidge                                       Bullet Train  08-11
# 5   Coolidge                                       Bullet Train  08-11
# 6   Coolidge  The Origins of American Independent Cinema\n\n...  08-11
# 7   Coolidge                                         Rhinestone  08-11
# 8   Coolidge                                          Vengeance  08-11
# 9   Coolidge                  Everything Everywhere All at Once  08-11
# 10  Coolidge                                               Nope  08-12
# 11  Coolidge                                               Nope  08-12
# 12  Coolidge                                               Nope  08-12
# 13  Coolidge                                       Bullet Train  08-12
# 14  Coolidge                                       Bullet Train  08-12
# 15  Coolidge                                       Bullet Train  08-12
# 16  Coolidge                               Bodies Bodies Bodies  08-12
# 17  Coolidge                               Bodies Bodies Bodies  08-12
# 18  Coolidge                               Bodies Bodies Bodies  08-12
# 19  Coolidge                                          Vengeance  08-12
#
#        time                                               link  \
# 0   3:30 PM  https://store.coolidge.org/websales/pages/Tick...
# 1   6:30 PM  https://store.coolidge.org/websales/pages/Tick...
# 2   9:45 PM  https://store.coolidge.org/websales/pages/Tick...
# 3   4:00 PM  https://store.coolidge.org/websales/pages/Tick...
# 4   7:15 PM  https://store.coolidge.org/websales/pages/Tick...
# 5   9:55 PM  https://store.coolidge.org/websales/pages/Tick...
# 6   6:30 PM  https://store.coolidge.org/websales/pages/entr...
# 7   7:00 PM  https://store.coolidge.org/websales/pages/Tick...
# 8   9:15 PM  https://store.coolidge.org/websales/pages/Tick...
# 9   9:30 PM  https://store.coolidge.org/websales/pages/Tick...
# 10  3:30 PM  https://store.coolidge.org/websales/pages/Tick...
# 11  7:00 PM  https://store.coolidge.org/websales/pages/Tick...
# 12  9:55 PM  https://store.coolidge.org/websales/pages/Tick...
# 13  4:00 PM  https://store.coolidge.org/websales/pages/Tick...
# 14  6:30 PM  https://store.coolidge.org/websales/pages/Tick...
# 15  9:15 PM  https://store.coolidge.org/websales/pages/Tick...
# 16  4:45 PM  https://store.coolidge.org/websales/pages/Tick...
# 17  7:15 PM  https://store.coolidge.org/websales/pages/Tick...
# 18  9:30 PM  https://store.coolidge.org/websales/pages/Tick...
# 19  6:45 PM  https://store.coolidge.org/websales/pages/Tick...
#
#                                                poster
# 0   https://www.coolidge.org/sites/default/files/s...
# 1   https://www.coolidge.org/sites/default/files/s...
# 2   https://www.coolidge.org/sites/default/files/s...
# 3   https://www.coolidge.org/sites/default/files/s...
# 4   https://www.coolidge.org/sites/default/files/s...
# 5   https://www.coolidge.org/sites/default/files/s...
# 6   https://www.coolidge.org/sites/default/files/s...
# 7   https://www.coolidge.org/sites/default/files/s...
# 8   https://www.coolidge.org/sites/default/files/s...
# 9   https://www.coolidge.org/sites/default/files/s...
# 10  https://www.coolidge.org/sites/default/files/s...
# 11  https://www.coolidge.org/sites/default/files/s...
# 12  https://www.coolidge.org/sites/default/files/s...
# 13  https://www.coolidge.org/sites/default/files/s...
# 14  https://www.coolidge.org/sites/default/files/s...
# 15  https://www.coolidge.org/sites/default/files/s...
# 16  https://www.coolidge.org/sites/default/files/s...
# 17  https://www.coolidge.org/sites/default/files/s...
# 18  https://www.coolidge.org/sites/default/files/s...
# 19  https://www.coolidge.org/sites/default/files/s...

# %% [markdown]
# ## Somerville Theater

# %%
s_url = 'https://www.somervilletheatre.com/wp-content/themes/somerville/showtimes.xml'
s_results = requests.get(s_url)

s_soup = BeautifulSoup(s_results.text, 'xml')
s_soup = s_soup.find_all('filmtitle')

# %%
# should use the `titlecase` package
# TODO: change titlecase import
get_title_raw = lambda x: titlecase.titlecase(x.find('name').text)
get_title = lambda x: re.sub(r'(\d\dm{1,2})|(4k)|(Masked Matinees:)', '', get_title_raw(x)).strip()
get_time_raw = lambda x: x.find('show').find('time').text 
get_time = lambda x: datetime.strptime(str(int(get_time_raw(x))//100), '%H').strftime('%l:%M %p').strip()
get_date_raw = lambda x: x.find('show').find('date').text 
get_date = lambda x: datetime.strptime(get_date_raw(x), '%m%d%Y').strftime('%m-%d')
get_link = lambda x: x.show.salelink.text

# %%
somerville_df = pd.DataFrame([{'theater': 'Somerville',
                                 'title': get_title(x), 
                                 'date': get_date(x),
                                 'time': get_time(x),
                                 'link': get_link(x),
                                } for x in s_soup])

somerville_df.to_csv('data/somerville.csv', index=False)

# %%
somerville_df = pd.read_csv('data/somerville.csv')
somerville_df
# Out:
#        theater                      title   date      time  \
# 0   Somerville       Bodies Bodies Bodies  08-12   5:00 PM
# 1   Somerville               Bullet Train  08-11   5:00 PM
# 2   Somerville                   Crooklyn  08-24   9:00 PM
# 3   Somerville              Dirty Dancing  08-22   7:00 PM
# 4   Somerville         Do the Right Thing  08-24   7:00 PM
# 5   Somerville            Friday the 13th  08-27  11:00 PM
# 6   Somerville              I Love My Dad  08-11   5:00 PM
# 7   Somerville           Ingrid Goes West  08-17   7:00 PM
# 8   Somerville                   Mermaids  08-15   7:00 PM
# 9   Somerville                  Midsommar  08-28   1:00 PM
# 10  Somerville                  Nashville  08-30   7:00 PM
# 11  Somerville                       Nope  08-11   5:00 PM
# 12  Somerville               Now and Then  08-22   9:00 PM
# 13  Somerville             On Golden Pond  08-26   7:00 PM
# 14  Somerville                    Robocop  08-19   9:00 PM
# 15  Somerville    Season of the Witch '72  08-28   4:00 PM
# 16  Somerville  Sisterhood of the Traveli  08-15   9:00 PM
# 17  Somerville                Stand by Me  08-26   5:00 PM
# 18  Somerville             The Terminator  08-20  11:00 PM
# 19  Somerville             The to-Do List  08-17   9:00 PM
#
#                                                  link
# 0   https://20163.formovietickets.com:2235/T.ASP?W...
# 23   2:00 PM  https://store.coolidge.org/websales/pages/Tick...
# 28   2:15 PM  https://store.coolidge.org/websales/pages/Tick...
# 4    3:00 PM       https://brattlefilm.org/movies/blonde-venus/
# 24   3:55 PM  https://store.coolidge.org/websales/pages/Tick...
# 38   4:00 PM  https://store.coolidge.org/websales/pages/Tick...
# 34   4:30 PM  https://store.coolidge.org/websales/pages/Tick...
# 29   4:45 PM  https://store.coolidge.org/websales/pages/Tick...
# 5    5:00 PM   https://brattlefilm.org/movies/shanghai-express/
# 25   6:30 PM  https://store.coolidge.org/websales/pages/Tick...
# 35   6:45 PM  https://store.coolidge.org/websales/pages/Tick...
# 39   7:00 PM  https://store.coolidge.org/websales/pages/Tick...
# 30   7:15 PM  https://store.coolidge.org/websales/pages/Tick...
# 36   9:00 PM  https://store.coolidge.org/websales/pages/Tick...
# 26   9:15 PM  https://store.coolidge.org/websales/pages/Tick...
#
#                                                poster
# 0   https://www.coolidge.org/sites/default/files/s...
# 3   https://www.coolidge.org/sites/default/files/s...
# 1                                                 NaN
# 6                                                 NaN
# 11                                                NaN
# 1   https://www.coolidge.org/sites/default/files/s...
# 6   https://www.coolidge.org/sites/default/files/s...
# 0   https://s3.amazonaws.com/nightjarprod/content/...
# 7   https://www.coolidge.org/sites/default/files/s...
# 4   https://www.coolidge.org/sites/default/files/s...
# 8   https://www.coolidge.org/sites/default/files/s...
# 9   https://www.coolidge.org/sites/default/files/s...
# 1   https://s3.amazonaws.com/nightjarprod/content/...
# 2   https://www.coolidge.org/sites/default/files/s...
# 5   https://www.coolidge.org/sites/default/files/s...
# 21  https://www.coolidge.org/sites/default/files/s...
# 10  https://www.coolidge.org/sites/default/files/s...
# 13  https://www.coolidge.org/sites/default/files/s...
# 16  https://www.coolidge.org/sites/default/files/s...
# 2   https://s3.amazonaws.com/nightjarprod/content/...
# 0                                                 NaN
# 14  https://www.coolidge.org/sites/default/files/s...
# 19  https://www.coolidge.org/sites/default/files/s...
# 3   https://s3.amazonaws.com/nightjarprod/content/...
# 11  https://www.coolidge.org/sites/default/files/s...
# 17  https://www.coolidge.org/sites/default/files/s...
# 20  https://www.coolidge.org/sites/default/files/s...
# 15  https://www.coolidge.org/sites/default/files/s...
# 18  https://www.coolidge.org/sites/default/files/s...
# 12  https://www.coolidge.org/sites/default/files/s...
# 22  https://www.coolidge.org/sites/default/files/s...
# 27  https://www.coolidge.org/sites/default/files/s...
# 32  https://www.coolidge.org/sites/default/files/s...
# 41  https://www.coolidge.org/sites/default/files/s...
# 37  https://www.coolidge.org/sites/default/files/s...
# 33  https://www.coolidge.org/sites/default/files/s...
# 23  https://www.coolidge.org/sites/default/files/s...
# 28  https://www.coolidge.org/sites/default/files/s...
# 4   https://s3.amazonaws.com/nightjarprod/content/...
# 24  https://www.coolidge.org/sites/default/files/s...
# 38  https://www.coolidge.org/sites/default/files/s...
# 34  https://www.coolidge.org/sites/default/files/s...
# 29  https://www.coolidge.org/sites/default/files/s...
# 5   https://s3.amazonaws.com/nightjarprod/content/...
# 25  https://www.coolidge.org/sites/default/files/s...
# 35  https://www.coolidge.org/sites/default/files/s...
# 39  https://www.coolidge.org/sites/default/files/s...
# 30  https://www.coolidge.org/sites/default/files/s...
# 36  https://www.coolidge.org/sites/default/files/s...
# 26  https://www.coolidge.org/sites/default/files/s...

# %% [markdown]
# ## Rotten Tomates for poster art and rating

# %%
def get_rt_info(query):
    N = 4 # number of entries to consider
    query = urllib.parse.quote(query)
    url = "https://rottentomatoes.com/search?search='{query}'"
    url = url.format(query=query)
    result = requests.get(url)
    soup = BeautifulSoup(result.content, 'html.parser')
    movie_section = soup.find('h2', attrs={'data-qa': 'search-result-title'}, text='Movies')
    listings = movie_section.find_next_sibling('ul').find_all('search-page-media-row')
    scores = [int(m['tomatometerscore']) if m['tomatometerscore'].isnumeric() else 0 for m in listings]
    entry = listings[np.argmax(scores[:4])]
    try:
        rt_info = {
            'title': entry.text.strip(),
            'poster': entry.img['src'],
            'year': entry['releaseyear'],
            'cast': entry['cast'],
            'score': entry['tomatometerscore'], # technically redundant
            'cert': entry['tomatometerstate'],
            'rt_link': entry.a['href']
            }
    except:
        return None
    return rt_info

# %%
# %%time
# example
get_rt_info("Pee wee's big aventure")
# Out:
# CPU times: user 105 ms, sys: 7.73 ms, total: 113 ms
# Wall time: 2.3 s
# {'title': "Pee-wee's Big Adventure",
#  'poster': 'https://resizing.flixster.com/dX5asNZ4f_a6UPp8E9xS_IrZXqE=/fit-in/80x126/v2/https://flxt.tmsimg.com/assets/p8533_p_v8_ab.jpg',
#  'year': '1985',
#  'cast': 'Paul Reubens,Elizabeth Daily,Mark Holton',
#  'score': '87',
#  'cert': 'certified-fresh',
#  'rt_link': 'https://www.rottentomatoes.com/m/peewees_big_adventure'}

# %%
# %%time
titles = df.title.unique()
rt_data = []
for t in titles:
    try:
        d = get_rt_info(t)
        d.update(listing_title=t)
        rt_data.append(d)
    except:
        print(t)
    time.sleep(0.1)
# Out:
# CPU times: user 11 s, sys: 256 ms, total: 11.3 s
# Wall time: 1min 45s

# %%
rt_df = pd.DataFrame(rt_data)
rt_df.to_csv('data/rt.csv', index=False)

# %%
rt_df = pd.read_csv('data/rt.csv')
rt_df.head()
# Out:
#                                                title  \
# 0                                               Nope
# 1                                       Bullet Train
# 2                                      I Love My Dad
# 3  The Decline of Western Civilization Part II: T...
# 4                          Tinker Tailor Soldier Spy
#
#                                               poster  year  \
# 0  https://resizing.flixster.com/RqUUghr84Wd1Mdr_...  2022
# 1  https://resizing.flixster.com/5_452AiySCc1Qedp...  2022
# 2  https://resizing.flixster.com/jPHL1K2L_bj5NfXF...  2022
# 3  https://resizing.flixster.com/QQiD-pdoCgPxeXyH...  1988
# 4  https://resizing.flixster.com/JXiB5VkW7LCXm-V_...  2011
#
#                                             cast  score             cert  \
# 0         Daniel Kaluuya,Keke Palmer,Steven Yeun   82.0  certified-fresh
# 1       Brad Pitt,Joey King,Aaron Taylor-Johnson   54.0           rotten
# 2  Patton Oswalt,James Morosini,Claudia Sulewski   70.0            fresh
# 3            Steven Tyler,Joe Perry,Alice Cooper   91.0            fresh
# 4   Gary Oldman,Kathy Burke,Benedict Cumberbatch   84.0  certified-fresh
#
#                                              rt_link  \
# 0              https://www.rottentomatoes.com/m/nope
# 1  https://www.rottentomatoes.com/m/bullet_train_...
# 2     https://www.rottentomatoes.com/m/i_love_my_dad
# 3  https://www.rottentomatoes.com/m/decline_of_we...
# 4  https://www.rottentomatoes.com/m/tinker_tailor...
#
#                                        listing_title
# 0                                               Nope
# 1                                       Bullet Train
# 2                                      I Love My Dad
# 3  The Origins of American Independent Cinema\n\n...
# 4                                            El Topo

# %%
merged = pd.merge(df, rt_df, left_on='title', right_on='listing_title')

# %%
merged.columns
# Out:
# Index(['theater', 'title_x', 'date', 'time', 'link', 'poster_x', 'title_y',
#        'poster_y', 'year', 'cast', 'score', 'cert', 'rt_link',
#        'listing_title'],
#       dtype='object')

# %%
merged = merged.drop(['listing_title', 'poster_x', 'title_y'], axis=1)\
               .rename(columns={'title_x': 'title', 'poster_y': 'poster'})

# %%
output = merged[['theater', 'poster', 'title', 'year', 'date', 'time', 'link', 'score', 'rt_link']].sort_values(['date','time'])

# %%
output['poster']=  '''<img src="''' + output['poster'] + '''">''' 
output['link'] = output.link.apply(lambda x: f"<a href={x}>🎟️</a>")
output['rt_link'] = output.rt_link.apply(lambda x: f"<a href={x}>🍅</a>")

# %%
output.to_csv("data/showtimes.csv")

# %% [markdown]
# # Showtimes

# %%
HTML(output.to_html(render_links=True, escape=False, index=False, justify='center'))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th>theater</th>
#       <th>poster</th>
#       <th>title</th>
#       <th>year</th>
#       <th>date</th>
#       <th>time</th>
#       <th>link</th>
#       <th>score</th>
#       <th>rt_link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/RqUUghr84Wd1Mdr_7PStmSQXXhM=/fit-in/80x126/v2/https://resizing.flixster.com/6EeYrywKueOFue9uRSQqLxfGKI0=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzA0NzZhZTk0LTI3NjctNGZiNi04Yjg4LWRiN2RkNTJiYWZlNy5qcGc="></td>
#       <td>Nope</td>
#       <td>2022</td>
#       <td>08-11</td>
#       <td>3:30 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=749369~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>82.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/nope>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/5_452AiySCc1Qedpa-ZAgkKBozI=/fit-in/80x126/v2/https://resizing.flixster.com/0Wuqfdlk2B3QUnrB7wPlQ7c47AI=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL
/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzdiZTdkNDdlLWE5M2EtNDNhNC1hYWE2LTljYzJjYjc3ZDc2OC5qcGc="></td>
#       <td>Vengeance</td>
#       <td>2022</td>
#       <td>08-11</td>
#       <td>9:15 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=749415~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>79.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/vengeance_2022>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/C5O31DhdXHTkCQ-Ux0jWwnC0E_Q=/fit-in/80x126/v2/https://resizing.flixster.com/mx-agGjjsUK1QMyuv3AJhHI3hgo=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzA3ZjU2MGU1LWMxODItNDlkMC1hYzJhLTY2YzMwOGZkMDhiZi5qcGc="></td>
#       <td>Everything Everywhere All at Once</td>
#       <td>2022</td>
#       <td>08-11</td>
#       <td>9:30 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=749410~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>95.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/everything_everywhere_all_at_once>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/RqUUghr84Wd1Mdr_7PStmSQXXhM=/fit-in/80x126/v2/https://resizing.flixster.com/6EeYrywKueOFue9uRSQqLxfGKI0=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzA0NzZhZTk0LTI3NjctNGZiNi04Yjg4LWRiN2RkNTJiYWZlNy5qcGc="></td>
#       <td>Nope</td>
#       <td>2022</td>
#       <td>08-11</td>
#       <td>9:45 PM</td>
#       <td><a href=https://store.coolidge

# %% [markdown]
# # Testing...

# %%
s = '<img src=https://resizing.flixster.com/Zd9kpD_evBsdOqXQuVj8t0s4JYE=/fit-in/80x126/v2/https://resizing.flixster.com/y629Pkvr6tTHrzCEOd5XgLtGuxE=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzMyODliMzFlLTMwZmEtNDZjOC04Zjk5LWMwNTIyNGEzYjVlNC5qcGc=>'

# %%
q = "The Wizard of Oz"
results = requests.get(f'https://rottentomatoes.com/search?search={q}')
soup = BeautifulSoup(results.content, 'html.parser')

# %%
# soup.find('ul', slot='list')

# soup.find('search-page-media-row')

# %% [markdown]
# **Different movies playing today**

# %%
df[df['date'] == date.today().strftime('%m-%d')].title.unique()
# Out:
# array(['Nope', 'Bullet Train', 'I Love My Dad',
#        'The Origins of American Independent Cinema\n\n\n\nPart of\xa0The Origins of American Independent Cinema',
#        'El Topo', 'Rhinestone', 'Vengeance',
#        'Everything Everywhere All at Once', 'The Holy Mountain'],
#       dtype=object)
