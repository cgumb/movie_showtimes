# %% [markdown]
# # [Jump to Movie Showtimes](#Showtimes)

# %%
from datetime import date, datetime, timedelta
import time
import re
import urllib
import numpy as np
import requests
import titlecase
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display, HTML

# %%
url = 'https://brattlefilm.org/coming-soon/'
response = requests.get(url)

# %%
text = response.text
text[:300]
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n\n<head>\n\n\n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t<link rel="profile" href="http://gmpg.org/xfn/11">\n\t<link rel="pingback" href="https://brattlef'

# %%
soup = BeautifulSoup(text, 'html.parser')

# %%
show_details = soup.find_all('div', 'show-details')

# %%
get_dates_raw = lambda x: [' '.join(d.text.split()[1:]) for d in x.find_all('li', 'show-date')]
get_dates = lambda x: [datetime.strptime(d, "%b %d").strftime('%m-%d') for d in get_dates_raw(x)]
get_times = lambda x: [t.text.strip().split('\t')[0].upper() for t in x.find_all('a', 'showtime')]
get_title = lambda x: x.find('a', 'title').text
get_link = lambda x: x.find('a', 'title')['href']
get_poster = lambda x: x.find('div', 'show-poster').img['src']

# %%
brattle_df = pd.DataFrame([{'theater': 'Brattle',
                            'title': get_title(x),
                            'date': d,
                            'time': t,
                            'link': get_link(x),
                            'poster': get_poster(x)}
                           for x in show_details for d,t in list(zip(get_dates(x), get_times(x)))])

# %%
brattle_df.to_csv('data/brattle.csv', index=False)

# %%
brattle_df = pd.read_csv('data/brattle.csv')
brattle_df.head()
# Out:
#    theater                                             title   date     time  \
# 0  Brattle                                      Lost Highway  07-03  9:30 PM
# 1  Brattle                           Pee-wee’s Big Adventure  07-04  1:00 PM
# 2  Brattle                                      Midnight Run  07-05  3:45 PM
# 3  Brattle  Harvard Book Store presents Patrick Radden Keefe  07-06  6:00 PM
# 4  Brattle                                      Queen & Slim  07-07  3:45 PM
#
#                                                 link  \
# 0       https://brattlefilm.org/movies/lost-highway/
# 1  https://brattlefilm.org/movies/pee-wees-big-ad...
# 2       https://brattlefilm.org/movies/midnight-run/
# 3  https://brattlefilm.org/special_events/harvard...
# 4         https://brattlefilm.org/movies/queen-slim/
#
#                                               poster
# 0  https://s3.amazonaws.com/nightjarprod/content/...
# 1  https://s3.amazonaws.com/nightjarprod/content/...
# 2  https://s3.amazonaws.com/nightjarprod/content/...
# 3  https://s3.amazonaws.com/nightjarprod/content/...
# 4  https://s3.amazonaws.com/nightjarprod/content/...

# %% [markdown]
# # Coolidge

# %%
N = 60 # Number of days scrape
start_date = date.today()
cur_date = start_date
dates = [(start_date + timedelta(days=n)).strftime('%Y-%m-%d') for n in range(N)]
coolidge_url = 'https://coolidge.org/showtimes?date={date}'

# %%
def film_soup(url):
    c_results = requests.get(url)
    c_soup = BeautifulSoup(c_results.text, 'html.parser')
    c_films = (c_soup.find_all('div', 'film-card'))
    # filter out weird 'ResultSet' objects appearing in results
    c_films = [f for f in c_films if (str(type(f)) == "<class 'bs4.element.Tag'>")] 
    return c_films

# %%
get_title_raw = lambda x: x.find('div', 'film-card__title').text.strip()
get_title = lambda x: re.sub(r'Masked Matinees:', '', get_title_raw(x)).strip()
get_times = lambda x: [t.text.strip() for t in x.find_all('span', 'showtime-ticket__time')]
get_links = lambda x: [t['href'] for t in x.find_all('a', 'showtime-ticket__button')]
get_poster = lambda x: f"https://www.coolidge.org{x.picture.find_all('source')[-1]['srcset'].split()[0]}"

# %%
coolidge_shows = []
for d in dates:
    url =  coolidge_url.format(date=d)
    soup = film_soup(url)
    coolidge_shows.extend([{'theater': 'Coolidge',
                            'title': get_title(x),
                            'date': datetime.strptime(d, "%Y-%m-%d").strftime('%m-%d'),
                            'time': re.sub('(am|pm)', ' \g<1>', t).upper(),
                            'link': l,
                            'poster': get_poster(x)}
                           for x in soup for t, l in zip(get_times(x), get_links(x))])
                           # for t in get_times(x) for x in soup])

# %%
coolidge_df = pd.DataFrame(coolidge_shows)
coolidge_df.to_csv('data/coolidge.csv', index=False)

# %%
coolidge_df = pd.read_csv('data/coolidge.csv')
coolidge_df.head()
# Out:
#     theater                           title   date      time  \
# 0  Coolidge  Marcel the Shell with Shoes On  07-03  11:00 AM
# 1  Coolidge              Mr. Malcolm’s List  07-03  11:30 AM
# 2  Coolidge              Mr. Malcolm’s List  07-03   2:00 PM
# 3  Coolidge              Mr. Malcolm’s List  07-03   4:30 PM
# 4  Coolidge              Mr. Malcolm’s List  07-03   7:00 PM
#
#                                                 link  \
# 0  https://store.coolidge.org/websales/pages/Tick...
# 1  https://store.coolidge.org/websales/pages/Tick...
# 2  https://store.coolidge.org/websales/pages/Tick...
# 3  https://store.coolidge.org/websales/pages/Tick...
# 4  https://store.coolidge.org/websales/pages/Tick...
#
#                                               poster
# 0  https://www.coolidge.org/sites/default/files/s...
# 1  https://www.coolidge.org/sites/default/files/s...
# 2  https://www.coolidge.org/sites/default/files/s...
# 3  https://www.coolidge.org/sites/default/files/s...
# 4  https://www.coolidge.org/sites/default/files/s...

# %% [markdown]
# ## Somerville Theater

# %%
s_url = 'https://www.somervilletheatre.com/wp-content/themes/somerville/showtimes.xml'
s_results = requests.get(s_url)

# %%
s_soup = BeautifulSoup(s_results.text, 'xml')
s_soup = s_soup.find_all('filmtitle')

# %%
# should use the `titlecase` package
# TODO: change titlecase import
get_title_raw = lambda x: titlecase.titlecase(x.find('name').text)
get_title = lambda x: re.sub(r'(\d\dm{1,2})|(4k)|(Masked Matinees:)', '', get_title_raw(x)).strip()
get_time_raw = lambda x: x.find('show').find('time').text 
get_time = lambda x: datetime.strptime(str(int(get_time_raw(x))//100), '%H').strftime('%l:%M %p').strip()
get_date_raw = lambda x: x.find('show').find('date').text 
get_date = lambda x: datetime.strptime(get_date_raw(x), '%m%d%Y').strftime('%m-%d')
get_link = lambda x: x.show.salelink.text

# %%
somerville_df = pd.DataFrame([{'theater': 'Somerville',
                                 'title': get_title(x), 
                                 'date': get_date(x),
                                 'time': get_time(x),
                                 'link': get_link(x),
                                } for x in s_soup])

somerville_df.to_csv('data/somerville.csv', index=False)

# %%
# 18  https://www.coolidge.org/sites/default/files/s...
# 22  https://www.coolidge.org/sites/default/files/s...
# 29  https://www.coolidge.org/sites/default/files/s...
# 26  https://www.coolidge.org/sites/default/files/s...
# 19  https://www.coolidge.org/sites/default/files/s...
# 23  https://www.coolidge.org/sites/default/files/s...
# 27  https://www.coolidge.org/sites/default/files/s...
# 20  https://www.coolidge.org/sites/default/files/s...
# 30  https://www.coolidge.org/sites/default/files/s...
# 24  https://www.coolidge.org/sites/default/files/s...
# 31  https://www.coolidge.org/sites/default/files/s...
# 2   https://s3.amazonaws.com/nightjarprod/content/...
# 33  https://www.coolidge.org/sites/default/files/s...
# 36  https://www.coolidge.org/sites/default/files/s...
# 39  https://www.coolidge.org/sites/default/files/s...
# 34  https://www.coolidge.org/sites/default/files/s...
# 40  https://www.coolidge.org/sites/default/files/s...
# 16                                                NaN
# 37  https://www.coolidge.org/sites/default/files/s...
# 32  https://www.coolidge.org/sites/default/files/s...
# 2                                                 NaN
# 35  https://www.coolidge.org/sites/default/files/s...
# 38  https://www.coolidge.org/sites/default/files/s...

# %%
def get_rt_info(query):
    N = 4 # number of entries to consider
    query = urllib.parse.quote(query)
    url = "https://rottentomatoes.com/search?search='{query}'"
    url = url.format(query=query)
    result = requests.get(url)
    soup = BeautifulSoup(result.content, 'html.parser')
    movie_section = soup.find('h2', attrs={'data-qa': 'search-result-title'}, text='Movies')
    listings = movie_section.find_next_sibling('ul').find_all('search-page-media-row')
    scores = [int(m['tomatometerscore']) if m['tomatometerscore'].isnumeric() else 0 for m in listings]
    entry = listings[np.argmax(scores[:4])]
    try:
        rt_info = {
            'title': entry.text.strip(),
            'poster': entry.img['src'],
            'year': entry['releaseyear'],
            'cast': entry['cast'],
            'score': entry['tomatometerscore'], # technically redundant
            'cert': entry['tomatometerstate'],
            'rt_link': entry.a['href']
            }
    except:
        return None
    return rt_info

# %%
# %%time
get_rt_info("Pee wee's big aventure")
# Out:
# CPU times: user 99.5 ms, sys: 0 ns, total: 99.5 ms
# Wall time: 1.05 s
# {'title': "Pee-wee's Big Adventure",
#  'poster': 'https://resizing.flixster.com/dX5asNZ4f_a6UPp8E9xS_IrZXqE=/fit-in/80x126/v2/https://flxt.tmsimg.com/assets/p8533_p_v8_ab.jpg',
#  'year': '1985',
#  'cast': 'Paul Reubens,Elizabeth Daily,Mark Holton',
#  'score': '87',
#  'cert': 'certified-fresh',
#  'rt_link': 'https://www.rottentomatoes.com/m/peewees_big_adventure'}

# %%
# %%time
titles = df.title.unique()
rt_data = []
for t in titles:
    try:
        d = get_rt_info(t)
        d.update(listing_title=t)
        rt_data.append(d)
    except:
        print(t)
    time.sleep(0.25)
# Out:
# Judgment at Nuremberg
# CPU times: user 17 s, sys: 517 ms, total: 17.5 s
# Wall time: 7min 45s

# %%
rt_df = pd.DataFrame(rt_data)
rt_df.to_csv('data/rt.csv', index=False)

# %%
rt_df = pd.read_csv('data/rt.csv')
rt_df.head()
# Out:
#                             title  \
# 0  Marcel the Shell with Shoes On
# 1              Mr. Malcolm's List
# 2                           Elvis
# 3            Official Competition
# 4               Top Gun: Maverick
#
#                                               poster  year  \
# 0  https://resizing.flixster.com/Zd9kpD_evBsdOqXQ...  2021
# 1  https://resizing.flixster.com/brGS1xAm7lsZweH7...  2022
# 2  https://resizing.flixster.com/Jyfwrykf_WmlzzjE...  2022
# 3  https://resizing.flixster.com/dTWt1cvRxbQfrGC_...  2021
# 4  https://resizing.flixster.com/mUdgPGdb-0EmWSiG...  2022
#
#                                             cast  score             cert  \
# 0           Jenny Slate,Rosa Salazar,Thomas Mann  100.0  certified-fresh
# 1  Freida Pinto,Sope Dirisu,Oliver Jackson-Cohen   80.0            fresh
# 2          Austin Butler,Tom Hanks,Helen Thomson   78.0  certified-fresh
# 3  Penélope Cruz,Antonio Banderas,Oscar Martínez   96.0  certified-fresh
# 4      Tom Cruise,Miles Teller,Jennifer Connelly   96.0  certified-fresh
#
#                                              rt_link  \
# 0  https://www.rottentomatoes.com/m/marcel_the_sh...
# 1  https://www.rottentomatoes.com/m/mr_malcolms_list
# 2             https://www.rottentomatoes.com/m/elvis
# 3  https://www.rottentomatoes.com/m/official_comp...
# 4  https://www.rottentomatoes.com/m/top_gun_maverick
#
#                     listing_title
# 0  Marcel the Shell with Shoes On
# 1              Mr. Malcolm’s List
# 2                           Elvis
# 3            Official Competition
# 4                Top Gun Maverick

# %%
merged = pd.merge(df, rt_df, left_on='title', right_on='listing_title')

# %%
merged.columns
# Out:
# Index(['theater', 'title_x', 'date', 'time', 'link', 'poster_x', 'title_y',
#        'poster_y', 'year', 'cast', 'score', 'cert', 'rt_link',
#        'listing_title'],
#       dtype='object')

# %%
merged = merged.drop(['listing_title', 'poster_x', 'title_y'], axis=1)\
               .rename(columns={'title_x': 'title', 'poster_y': 'poster'})

# %%
output = merged[['theater', 'poster', 'title', 'year', 'date', 'time', 'link', 'score', 'rt_link']].sort_values(['date','time'])

# %%
output['poster']=  '''<img src="''' + output['poster'] + '''">''' 
output['link'] = output.link.apply(lambda x: f"<a href={x}>🎟️</a>")
output['rt_link'] = output.rt_link.apply(lambda x: f"<a href={x}>🍅</a>")

# %% [markdown]
# # Showtimes

# %%
HTML(output.to_html(render_links=True, escape=False, index=False, justify='center'))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th>theater</th>
#       <th>poster</th>
#       <th>title</th>
#       <th>year</th>
#       <th>date</th>
#       <th>time</th>
#       <th>link</th>
#       <th>score</th>
#       <th>rt_link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/Zd9kpD_evBsdOqXQuVj8t0s4JYE=/fit-in/80x126/v2/https://resizing.flixster.com/y629Pkvr6tTHrzCEOd5XgLtGuxE=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzMyODliMzFlLTMwZmEtNDZjOC04Zjk5LWMwNTIyNGEzYjVlNC5qcGc="></td>
#       <td>Marcel the Shell with Shoes On</td>
#       <td>2021</td>
#       <td>07-03</td>
#       <td>11:00 AM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=743961~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>100.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/marcel_the_shell_with_shoes_on>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/brGS1xAm7lsZweH7MX8LHfCS5ak=/fit-in/80x126/v2/https://resizing.flixster.com/klmXHtLoqJGKxwmON_LL7cJYXLg=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzA2ZTBkYzJkLTliYTEtNDZkZS05MWM0LTkyZDBlYTQ1M2VjNy5qcGc="></td>
#       <td>Mr. Malcolm’s List</td>
#       <td>2022</td>
#       <td>07-03</td>
#       <td>11:30 AM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=744520~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>80.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/mr_malcolms_list>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/Jyfwrykf_WmlzzjEf48yAkjX6j8=/fit-in/80x126/v2/https://resizing.flixster.com/mYfU74jKBCV9KA_O7ktmk5exwu4=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzczNjAwNTk0LTRlZWEtNDY5Ni1iYWM1LWRhZjI1OWUzODNhNy5qcGc="></td>
#       <td>Elvis</td>
#       <td>2022</td>
#       <td>07-03</td>
#       <td>12:30 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=744518~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>78.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/elvis>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Somerville</td>
#       <td><img src="https://resizing.flixster.com/Jyfwrykf_WmlzzjEf48yAkjX6j8=/fit-in/80x126/v2/https://resizing.flixster.com/mYfU74jKBCV9KA_O7ktmk5exwu4=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzczNjAwNTk0LTRlZWEtNDY5Ni1iYWM1LWRhZjI1OWUzODNhNy5qcGc="></td>
#       <td>Elvis</td>
#       <td>2022</td>
#       <td>07-03</td>
#       <td>1:00 PM</td>
#       <td><a href=https://20163.formovietickets.com:2235/T.ASP?WCI=BT&Page=PickTickets&SHOWID=42028&PLACEID=3>🎟️</a></td>
#       <td>78.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/elvis>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/dTWt1cvRxbQfrGC_51UnCdM5sAQ=/fit-in/80x126/v2/https://resizing.flixster.com/qzGq7siNCP4l-L5BgapjHogoQ0Y=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzA4ZTE5ZWUyLWViYzAtNDYzOS05MzI3LTkyYjYzNTg4NzQ1Yi5qcGc="></td>
#       <td>Official Competition</td>
#       <td>2021</td>
#       <td>07-03</td>
#       <td>1:00 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=744562~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>96.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/official_competition>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Somerville</td>
#       <td><img src="https://resizing.flixster.com/mUdgPGdb-0EmWSiG268x0-cY964=/fit-in/80x126/v2/https://resizing.flixster.com/TIM4kfHTVZrfpF0tYt9LIU69A5s=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzU1OWIwMWQwLWYyZDItNDk4Yi04MDIxLWI3OTJlNDI1NjA3NS5qcGc="></td>
#       <td>Top Gun Maverick</td>
#       <td>2022</td>
#       <td>07-03</td>
#       <td>1:00 PM</td>
#       <td><a href=https://20163.formovietickets.com:2235/T.ASP?WCI=BT&Page=PickTickets&SHOWID=42033&PLACEID=2>🎟️</a></td>
#       <td>96.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/top_gun_maverick>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/brGS1xAm7lsZweH7MX8LHfCS5ak=/fit-in/80x126/v2/https://resizing.flixster.com/klmXHtLoqJGKxwmON_LL7cJYXLg=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzA2ZTBkYzJkLTliYTEtNDZkZS05MWM0LTkyZDBlYTQ1M2VjNy5qcGc="></td>
#       <td>Mr. Malcolm’s List</td>
#       <td>2022</td>
#       <td>07-03</td>
#       <td>2:00 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=744511~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>80.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/mr_malcolms_list>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Somerville</td>
#       <td><img src="https://resizing.flixster.com/S8yJaHeRzCNtjnwuCp--Q8K84g4=/fit-in/80x126/v2/https://flxt.tmsimg.com/assets/p289_p_v8_ae.jpg"></td>
#       <td>Spartacus</td>
#       <td>1960</td>
#       <td>07-03</td>
#       <td>2:00 PM</td>
#       <td><a href=https://20163.formovietickets.com:2235/T.ASP?WCI=BT&Page=PickTickets&SHOWID=41801&PLACEID=1>🎟️</a></td>
#       <td>94.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/1019544-spartacus>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/Zd9kpD_evBsdOqXQuVj8t0s4JYE=/fit-in/80x126/v2/https://resizing.flixster.com/y629Pkvr6tTHrzCEOd5XgLtGuxE=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzMyODliMzFlLTMwZmEtNDZjOC04Zjk5LWMwNTIyNGEzYjVlNC5qcGc="></td>
#       <td>Marcel the Shell with Shoes On</td>
#       <td>2021</td>
#       <td>07-03</td>
#       <td>2:15 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=743964~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>100.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/marcel_the_shell_with_shoes_on>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/C5O31DhdXHTkCQ-Ux0jWwnC0E_Q=/fit-in/80x126/v2/https://resizing.flixster.com/mx-agGjjsUK1QMyuv3AJhHI3hgo=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzA3ZjU2MGU1LWMxODItNDlkMC1hYzJhLTY2YzMwOGZkMDhiZi5qcGc="></td>
#       <td>Everything Everywhere All at Once</td>
#       <td>2022</td>
#       <td>07-03</td>
#       <td>3:45 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=744529~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>95.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/everything_everywhere_all_at_once>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/Jyfwrykf_WmlzzjEf48yAkjX6j8=/fit-in/80x126/v2/https://resizing.flixster.com/mYfU74jKBCV9KA_O7ktmk5exwu4=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzczNjAwNTk0LTRlZWEtNDY5Ni1iYWM1LWRhZjI1OWUzODNhNy5qcGc="></td>
#       <td>Elvis</td>
#       <td>2022</td>
#       <td>07-03</td>
#       <td>4:00 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=744517~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>78.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/elvis>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/brGS1xAm7lsZweH7MX8LHfCS5ak=/fit-in/80x126/v2/https://resizing.flixster.com/klmXHtLoqJGKxwmON_LL7cJYXLg=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzA2ZTBkYzJkLTliYTEtNDZkZS05MWM0LTkyZDBlYTQ1M2VjNy5qcGc="></td>
#       <td>Mr. Malcolm’s List</td>
#       <td>2022</td>
#       <td>07-03</td>
#       <td>4:30 PM</td>
#       <td><a href=https://store.coolidge.org/websales/pages/TicketSearchCriteria.aspx?evtinfo=744508~2227d6a5-68f5-41c2-b22e-813c872c64f4&amp;>🎟️</a></td>
#       <td>80.0</td>
#       <td><a href=https://www.rottentomatoes.com/m/mr_malcolms_list>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Coolidge</td>
#       <td><img src="https://resizing.flixster.com/Zd9kpD_evBsdOqXQuVj8t0s4JYE=/fit-in/80x1

# %% [markdown]
# # Testing...

# %%
s = '<img src=https://resizing.flixster.com/Zd9kpD_evBsdOqXQuVj8t0s4JYE=/fit-in/80x126/v2/https://resizing.flixster.com/y629Pkvr6tTHrzCEOd5XgLtGuxE=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzMyODliMzFlLTMwZmEtNDZjOC04Zjk5LWMwNTIyNGEzYjVlNC5qcGc=>'

# %%
q = "The Wizard of Oz"
results = requests.get(f'https://rottentomatoes.com/search?search={q}')
soup = BeautifulSoup(results.content, 'html.parser')

# %%
# soup.find('ul', slot='list')

# soup.find('search-page-media-row')

# %% [markdown]
# **Different movies playing today**

# %%
df[df['date'] == date.today().strftime('%m-%d')].title.unique()
