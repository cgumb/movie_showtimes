# %%
import pandas as pd
from IPython.display import display, HTML
MIN_SCORE = 91
showtimes = pd.read_csv('data/showtimes.csv', index_col=0)
showtimes = showtimes[showtimes.score >= MIN_SCORE]
HTML(showtimes.to_html(render_links=True, escape=False, index=False, justify='center'))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th>theater</th>
#       <th>poster</th>
#       <th>exact_match</th>
#       <th>title</th>
#       <th>year</th>
#       <th>date</th>
#       <th>time</th>
#       <th>link</th>
#       <th>score</th>
#       <th>rt_link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Brattle</td>
#       <td><img src="https://resizing.flixster.com/fqr3YU30IPUch7fjFHSynG8nfVY=/fit-in/80x126/v2/https://flxt.tmsimg.com/assets/p1475_p_v8_aa.jpg"></td>
#       <td></td>
#       <td>For Me and My Gal</td>
#       <td>1942</td>
#       <td>08-15</td>
#       <td>4:15 PM</td>
#       <td><a href=https://brattlefilm.org/movies/for-me-and-my-gal/>🎟️</a></td>
#       <td>100</td>
#       <td><a href=https://www.rottentomatoes.com/m/for_me_and_my_gal>🍅</a></td>
#     </tr>
#     <tr>
#       <td>Brattle</td>
# ...
